# %%
from netCDF4 import Dataset
import numpy as np

# %%
#nc1 = Dataset('narr_latlon.nc','r',format='NETCDF4_CLASSIC')
#lats = nc1.variables["lats"][0][:][:]
#lons = nc1.variables["lons"][0][:][:]
#nc1.close()

######################################################

#Load 00-09 first
# stp_00z=np.load('/home/data/stp_narr/stp_00z.npy')
# stp_03z=np.load('/home/data/stp_narr/stp_03z.npy')
# stp_06z=np.load('/home/data/stp_narr/stp_06z.npy')
# stp_09z=np.load('/home/data/stp_narr/stp_09z.npy')

#Then do 12-21
# stp_12z=np.load('/home/data/stp_narr/stp_12z.npy')
# stp_15z=np.load('/home/data/stp_narr/stp_15z.npy')
# stp_18z=np.load('/home/data/stp_narr/stp_18z.npy')
# stp_21z=np.load('/home/data/stp_narr/stp_21z.npy')

#00-09
# stp_00z=np.squeeze(stp_00z,axis=1)
# stp_03z=np.squeeze(stp_03z,axis=1)
# stp_06z=np.squeeze(stp_06z,axis=1)
# stp_09z=np.squeeze(stp_09z,axis=1)
# stp_all_hrs = np.stack((stp_00z,stp_03z,stp_06z,stp_09z))

#12-21
# stp_12z=np.squeeze(stp_12z,axis=1)
# stp_15z=np.squeeze(stp_15z,axis=1)
# stp_18z=np.squeeze(stp_18z,axis=1)
# stp_21z=np.squeeze(stp_21z,axis=1)
# stp_all_hrs = np.stack((stp_12z,stp_15z,stp_18z,stp_21z))

#00-09
# print(stp_all_hrs.shape)
# np.save('narr_stp_00_09.npy',stp_all_hrs)

#12-21
# print(stp_all_hrs.shape)
# np.save('narr_stp_12_21.npy',stp_all_hrs)

######################################################

# stp00_09=np.load('/home/data/stp_narr/narr_stp_00_09.npy')

# stp00_09[stp00_09>=1.]==1.
# stp00_09[stp00_09<1.]==0.

# stp00_09_gt1 = np.mean(stp00_09,axis=2)

# np.save("narr_stp_00_09_mean_gt1.npy",stp00_09_gt1)

######################################################

# stp12_21=np.load('/home/data/stp_narr/narr_stp_12_21.npy')

# stp12_21[stp12_21>=1.]==1.
# stp12_21[stp12_21<1.]==0.

# stp12_21_gt1 = np.mean(stp12_21,axis=2)

# np.save("narr_stp_12_21_mean_gt1.npy",stp12_21_gt1)

#######################################################

# stp00_09=np.load('narr_stp_00_09_mean_gt1.npy')
# stp12_21=np.load('narr_stp_12_21_mean_gt1.npy')
# stp = np.stack((stp00_09,stp12_21))
# np.save("narr_stp_gt1_julday_climo_79_17.npy",stp)
#test=np.load('narr_stp_gt1_julday_climo_79_17.npy')
#print(test.shape)
#######################################################


# stp00_09=np.load('/home/data/stp_narr/narr_stp_00_09.npy')
# stp00_09[stp00_09>=1.]==1.
# stp00_09[stp00_09<1.]==0.
# stp00_09_gt1 = np.sum(stp00_09,axis=0)
# np.save("narr_stp_00to09_sum_gt1.npy",stp00_09_gt1)

#######################################################


# stp12_21=np.load('/home/data/stp_narr/narr_stp_12_21.npy')
# stp12_21[stp12_21>=1.]==1.
# stp12_21[stp12_21<1.]==0.
# stp12_21_gt1 = np.sum(stp12_21,axis=0)
# np.save("narr_stp_12to21_sum_gt1.npy",stp12_21_gt1)

#######################################################

# stp00_09=np.load('/home/data/stp_narr/narr_stp_00to09_sum_gt1.npy')
# stp12_21=np.load('/home/data/stp_narr/narr_stp_12to21_sum_gt1.npy')


# stp = np.stack((stp00_09,stp12_21))
# stp1 = np.sum(stp,axis=0)
# np.save("/home/data/stp_narr/narr_stp_gt1_diurnal_sum_79_17.npy",stp1)   #USE THIS ONE!!!!!!!!!
# print (stp1.shape)
#######################################################

#stp00_09 = np.load('/home/data/stp_narr/narr_stp_00_09.npy')
#stp00_09 = np.max(stp00_09,axis=0)
#np.save("narr_stp_00to09_max.npy",stp00_09)

# stp12_21 = np.load('/home/data/stp_narr/narr_stp_12_21.npy')
# stp12_21 = np.sum(stp12_21,axis=0)
# np.save("narr_stp_12to21_sum.npy",stp12_21)

##############################################################
# stp00_09=np.load('narr_stp_00to09_sum.npy')
# stp12_21=np.load('narr_stp_12to21_sum.npy')
# stp = np.stack((stp00_09,stp12_21))
# print(stp.shape)
# stp1 = np.sum(stp,axis=0)
# np.save("/home/data/stp_narr/narr_stp_diurnal_sum_79_17.npy",stp1) 
# print (stp1.shape)

# stp00_09=np.load('narr_stp_00to09_max.npy')
# stp12_21=np.load('narr_stp_12to21_max.npy')
# stp = np.stack((stp00_09,stp12_21))
# print(stp.shape)
# stp1 = np.max(stp,axis=0)
# np.save("/home/data/stp_narr/narr_stp_diurnal_max_79_17.npy",stp1) 

stp1 = np.load('/home/data/stp_narr/narr_stp_diurnal_max_79_17.npy')
print (stp1.shape)
print (stp1.max())
print("DONE")
# Out:
# (365, 39, 277, 349)
# 22.6484375
# DONE
